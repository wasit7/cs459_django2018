# %% [markdown]
# # Questions [40marks]
# * Q1 Who did spend most money for renting?
# * Q2 Which room does make the most amount of income?
# * Q3 How many time Jack Jones rent the room?
# * Q4 What are the roomss rented by Claire Taylor?
# * Q5 what is the total income of ALL rooms in June? Between 1st June 2018(inclusive) and 30th June 2018(inclusive), (use return date).
# * Q6 What are the total incomes of EACH room in June? Between 1st June 2018(inclusive) and 30th June 2018(inclusive), (use return date)
# * Q7 Find members that have total rent time exactly 8 hours in June?
# * Q8 Find members that have total rent time greater than or equal than 9 hours in June?
# * Q9 Find the total rent duration of EACH room in June?
# * Q10 Find the total income of EACH room in June?
#
# # คำถาม [ข้อละ 4 คะแนน รวม 40 คะแนน]
# * Q1 ใครจ่ายเงินค่าเช่ามากที่สุด
# * Q2 ห้องเช่าใดทำรายได้มากที่สุด
# * Q3 Jack Jones เช่าห้องไปกี่ครั้ง
# * Q4 Claire Taylor เช่าห้องไปกี่ครั้ง
# * Q5 ในเดือนมิถุนายนมีรายรับรวมเท่าใด
# * Q6 ในเดือนมิถุนายนแต่ละห้องมีรายรับรวมเท่าใด
# * Q7 หาชื่อสมาชิกที่เช่าห้อง 8 ชั่วโมงในเดือนมิถุนายน
# * Q8 หาชื่อสมาชิกที่เช่าห้องมากกว่าหรือเท่ากับ 9 ชั่วโมงในเดือนมิถุนายน
# * Q9 หาระยะเวลาเช่ารวมของแต่ละห้องในเดือนมิถุนายน
# * Q10 หารายได้รวมของแต่ละห้องในเดือนมิถุนายน

# %%
import sqlite3
import pandas as pd
con = sqlite3.connect('db.sqlite3')
df = pd.read_sql_query("SELECT * FROM sqlite_master", con)
df
# Out:
#      type                                               name  \
# 0   table                                  django_migrations
# 1   table                                    sqlite_sequence
# 2   table                                         auth_group
# 3   index                      sqlite_autoindex_auth_group_1
# 4   table                             auth_group_permissions
# 5   table                                   auth_user_groups
# 6   table                         auth_user_user_permissions
# 7   index  auth_group_permissions_group_id_permission_id_...
# 8   index           auth_group_permissions_group_id_b120cbf9
# 9   index      auth_group_permissions_permission_id_84c5c92e
# 10  index    auth_user_groups_user_id_group_id_94350c0c_uniq
# 11  index                  auth_user_groups_user_id_6a12ed8b
# 12  index                 auth_user_groups_group_id_97559544
# 13  index  auth_user_user_permissions_user_id_permission_...
# 14  index        auth_user_user_permissions_user_id_a95ead1b
# 15  index  auth_user_user_permissions_permission_id_1fbb5f2c
# 16  table                                   django_admin_log
# 17  index          django_admin_log_content_type_id_c4bce8eb
# 18  index                  django_admin_log_user_id_c564eba6
# 19  table                                django_content_type
# 20  index  django_content_type_app_label_model_76bd3d3b_uniq
# 21  table                                    auth_permission
# 22  index  auth_permission_content_type_id_codename_01ab3...
# 23  index           auth_permission_content_type_id_2f476e4b
# 24  table                                          auth_user
# 25  index                       sqlite_autoindex_auth_user_1
# 26  table                                       myapp_member
# 27  table                                     django_session
# 28  index                  sqlite_autoindex_django_session_1
# 29  index                django_session_expire_date_a5c62663
# 30  table                                         myapp_room
# 31  table                                         myapp_rent
# 32  index                      myapp_rent_member_id_c328ad0a
# 33  index                        myapp_rent_room_id_e0d974f9
#
#                       tbl_name  rootpage  \
# 0            django_migrations         2
# 1              sqlite_sequence         3
# 2                   auth_group         9
# 3                   auth_group        10
# 4       auth_group_permissions        11
# 5             auth_user_groups        15
# 6   auth_user_user_permissions        16
# 7       auth_group_permissions        20
# 8       auth_group_permissions        21
# 9       auth_group_permissions        23
# 10            auth_user_groups        24
# 11            auth_user_groups        25
# 12            auth_user_groups        26
# 13  auth_user_user_permissions        27
# 14  auth_user_user_permissions        29
# 15  auth_user_user_permissions        30
# 16            django_admin_log        35
# 17            django_admin_log        31
# 18            django_admin_log        33
# 19         django_content_type         5
# 20         django_content_type         4
# 21             auth_permission        34
# 22             auth_permission         6
# 23             auth_permission        18
# 24                   auth_user        12
# 25                   auth_user        13
# 26                myapp_member        19
# 27              django_session        42
# 28              django_session        43
# 29              django_session        44
# 30                  myapp_room        55
# 31                  myapp_rent       384
# 32                  myapp_rent        37
# 33                  myapp_rent       193
#
#                                                   sql
# 0   CREATE TABLE "django_migrations" ("id" integer...
# 1              CREATE TABLE sqlite_sequence(name,seq)
# 2   CREATE TABLE "auth_group" ("id" integer NOT NU...
# 3                                                None
# 4   CREATE TABLE "auth_group_permissions" ("id" in...
# 5   CREATE TABLE "auth_user_groups" ("id" integer ...
# 6   CREATE TABLE "auth_user_user_permissions" ("id...
# 7   CREATE UNIQUE INDEX auth_group_permissions_gro...
# 8   CREATE INDEX "auth_group_permissions_group_id_...
# 9   CREATE INDEX "auth_group_permissions_permissio...
# 10  CREATE UNIQUE INDEX auth_user_groups_user_id_g...
# 11  CREATE INDEX "auth_user_groups_user_id_6a12ed8...
# 12  CREATE INDEX "auth_user_groups_group_id_975595...
# 13  CREATE UNIQUE INDEX auth_user_user_permissions...
# 14  CREATE INDEX "auth_user_user_permissions_user_...
# 15  CREATE INDEX "auth_user_user_permissions_permi...
# 16  CREATE TABLE "django_admin_log" ("id" integer ...
# 17  CREATE INDEX "django_admin_log_content_type_id...
# 18  CREATE INDEX "django_admin_log_user_id_c564eba...
# 19  CREATE TABLE "django_content_type" ("id" integ...
# 20  CREATE UNIQUE INDEX django_content_type_app_la...
# 21  CREATE TABLE "auth_permission" ("id" integer N...
# 22  CREATE UNIQUE INDEX auth_permission_content_ty...
# 23  CREATE INDEX "auth_permission_content_type_id_...
# 24  CREATE TABLE "auth_user" ("id" integer NOT NUL...
# 25                                               None
# 26  CREATE TABLE "myapp_member" ("id" integer NOT ...
# 27  CREATE TABLE "django_session" ("session_key" v...
# 28                                               None
# 29  CREATE INDEX "django_session_expire_date_a5c62...
# 30  CREATE TABLE "myapp_room" ("id" integer NOT NU...
# 31  CREATE TABLE "myapp_rent" ("id" integer NOT NU...
# 32  CREATE INDEX "myapp_rent_member_id_c328ad0a" O...
# 33  CREATE INDEX "myapp_rent_room_id_e0d974f9" ON ...

# %%
df_member = pd.read_sql_query("SELECT * FROM myapp_member", con)
df_room = pd.read_sql_query("SELECT * FROM myapp_room", con)
df_rent = pd.read_sql_query("SELECT * FROM myapp_rent", con, parse_dates=['start','stop'])

# %%
df_member.head()
# Out:
#    id            name mobile
# 0   1  Oscar Williams
# 1   2     James Jones
# 2   3   Claire Thomas
# 3   4  Oliver Johnson
# 4   5    Oliver Jones

# %%
df_rent.head()
# Out:
#     id                      start                       stop  member_id  \
# 0  383 2018-05-09 08:01:18.462109 2018-05-09 09:01:18.462109         48
# 1  384 2018-05-09 08:01:18.462109 2018-05-09 10:01:18.462109          1
# 2  385 2018-05-09 09:01:18.462109 2018-05-09 10:01:18.462109         67
# 3  386 2018-05-09 10:01:18.462109 2018-05-09 12:01:18.462109         18
# 4  387 2018-05-09 12:01:18.462109 2018-05-09 15:01:18.462109         86
#
#    room_id   cost
# 0        7  100.0
# 1        9  260.0
# 2       10  199.0
# 3        7  200.0
# 4        6  315.0

# %%
df=df_member.merge(df_rent,how='inner',left_on='id',right_on='member_id')\
    .merge(df_room,left_on='room_id',right_on='id')

# %%
df.head()
# Out:
#    id_x            name mobile  id_y                      start  \
# 0     1  Oscar Williams          384 2018-05-09 08:01:18.462109
# 1     1  Oscar Williams          403 2018-05-10 04:01:18.462109
# 2     1  Oscar Williams          583 2018-05-18 08:01:18.462109
# 3     1  Oscar Williams          783 2018-05-26 11:01:18.462109
# 4     1  Oscar Williams          899 2018-05-31 03:01:18.462109
#
#                         stop  member_id  room_id   cost  id number  \
# 0 2018-05-09 10:01:18.462109          1        9  260.0   9    104
# 1 2018-05-10 05:01:18.462109          1        9  130.0   9    104
# 2 2018-05-18 10:01:18.462109          1        9  260.0   9    104
# 3 2018-05-26 15:01:18.462109          1        9  520.0   9    104
# 4 2018-05-31 05:01:18.462109          1        9  260.0   9    104
#
#    hour_price  isavailable
# 0         130            1
# 1         130            1
# 2         130            1
# 3         130            1
# 4         130            1

# %%
#Q3
df.groupby('name').agg({'room_id':'count'}).query('name=="Jack Jones"')
# Out:
#             room_id
# name
# Jack Jones       35

# %%
from datetime import datetime, timedelta
df['hours']=(df_rent.stop-df_rent.start).apply(lambda x: x.seconds)//3600
start = datetime.strptime( "2018-06-01T00:00:00", "%Y-%m-%dT%H:%M:%S" )
stop = datetime.strptime( "2018-06-30T23:59:59", "%Y-%m-%dT%H:%M:%S" )
df=df[(start<=df.start) & (df.stop<=stop)]
df
# Out:
#       id_x              name mobile  id_y                      start  \
# 5        1    Oscar Williams         1391 2018-06-21 04:01:18.462109
# 8        2       James Jones         1014 2018-06-05 15:01:18.462109
# 9        2       James Jones         1439 2018-06-23 10:01:18.462109
# 17       3     Claire Thomas          992 2018-06-04 07:01:18.462109
# 18       3     Claire Thomas         1435 2018-06-23 05:01:18.462109
# 22       4    Oliver Johnson         1304 2018-06-17 19:01:18.462109
# 26       5      Oliver Jones          943 2018-06-02 03:01:18.462109
# 27       5      Oliver Jones          997 2018-06-04 19:01:18.462109
# 32       6    Charlie Wilson         1088 2018-06-08 14:01:18.462109
# 33       6    Charlie Wilson         1575 2018-06-29 17:01:18.462109
# 42       7      Harry Thomas         1024 2018-06-05 21:01:18.462109
# 3319 2018-06-17 22:01:18.462109         84       10   199.0  10    105
# 3320 2018-06-18 07:01:18.462109         84       10   199.0  10    105
# 3321 2018-06-25 15:01:18.462109         84       10   199.0  10    105
# 3323 2018-06-14 11:01:18.462109         85       10   199.0  10    105
# 3324 2018-06-28 07:01:18.462109         85       10   398.0  10    105
# 3325 2018-06-30 07:01:18.462109         85       10   199.0  10    105
# 3338 2018-06-29 18:01:18.462109         87       10   398.0  10    105
# 3353 2018-06-10 08:01:18.462109         89       10   398.0  10    105
# 3364 2018-06-01 20:01:18.462109         92       10   796.0  10    105
# 3373 2018-06-24 08:01:18.462109         93       10   199.0  10    105
# 3380 2018-06-12 01:01:18.462109         94       10   199.0  10    105
# 3381 2018-06-15 22:01:18.462109         94       10   597.0  10    105
# 3390 2018-06-17 11:01:18.462109         95       10   199.0  10    105
# 3391 2018-06-25 16:01:18.462109         95       10   199.0  10    105
# 3396 2018-06-29 07:01:18.462109         96       10   199.0  10    105
# 3399 2018-06-12 07:01:18.462109         97       10   597.0  10    105
# 3410 2018-06-26 00:01:18.462109         99       10   398.0  10    105
# 3420 2018-06-04 08:01:18.462109        100       10   398.0  10    105
#
#       hour_price  isavailable  hours
# 5            130            1    1.0
# 8            130            1    3.0
# 9            130            1    1.0
# 17           130            1    1.0
# 18           130            1    1.0
# 22           130            1    2.0
# 26           130            1    1.0
# 27           130            1    1.0
# 32           130            1    1.0
# 33           130            1    2.0
# 42           130            1    1.0
# 49           130            1    1.0
# 53           130            1    2.0
# 54           130            1    5.0
# 55           130            1    1.0
# 74           130            1    2.0
# 75           130            1    1.0
# 82           130            1    2.0
# 83           130            1    3.0
# 88           130            1    1.0
# 93           130            1    2.0
# 94           130            1    2.0
# 95           130            1    1.0
# 98           130            1    4.0
# 99           130            1    2.0
# 100          130            1    2.0
# 129          130            1    1.0
# 130          130            1    2.0
# 138          130            1    2.0
# 158          130            1    4.0
# ...          ...          ...    ...
# 3263         199            1    9.0
# 3264         199            1    2.0
# 3273         199            1   10.0
# 3275         199            1    1.0
# 3276         199            1    1.0
# 3283         199            1    4.0
# 3284         199            1    1.0
# 3296         199            1    1.0
# 3302         199            1    1.0
# 3303         199            1    9.0
# 3304         199            1    3.0
# 3305         199            1    3.0
# 3319         199            1    1.0
# 3320         199            1    3.0
# 3321         199            1    1.0
# 3323         199            1    2.0
# 3324         199            1    1.0
# 3325         199            1    3.0
# 3338         199            1    2.0
# 3353         199            1    1.0
# 3364         199            1    1.0
# 3373         199            1    1.0
# 3380         199            1    1.0
# 3381         199            1    2.0
# 3390         199            1    1.0
# 3391         199            1    2.0
# 3396         199            1    2.0
# 3399         199            1    1.0
# 3410         199            1    1.0
# 3420         199            1    1.0
#
# [678 rows x 14 columns]

# %%
#Q7
df2=df.groupby('name').agg({'hours':'sum'})
df2.loc[df2.hours==8]
# Out:
#                   hours
# name
# Claire Williams     8.0
# George Wilson       8.0
# Jack Williams       8.0
# Jack Wilson         8.0
# Jacob Taylor        8.0
# Oscar Evans         8.0
# Thomas Smith        8.0
# William Williams    8.0
